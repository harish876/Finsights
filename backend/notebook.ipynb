# %%
from pydantic_settings import BaseSettings
from langchain_text_splitters import MarkdownHeaderTextSplitter
from langchain_community.embeddings.fastembed import FastEmbedEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_google_vertexai import ChatVertexAI
from langchain_community.document_loaders import UnstructuredMarkdownLoader
from langchain.prompts import PromptTemplate
from langchain.chains import RetrievalQA
from llama_parse import LlamaParse
import nltk

import pandas as pd
from collections import defaultdict
from tabulate import tabulate

import joblib
import os
import nest_asyncio  # noqa: E402
nest_asyncio.apply()

from pytablereader import MarkdownTableTextLoader


nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

from google.cloud import aiplatform
aiplatform.init(project="planar-cistern-448818-f5")
# Out:
# /Users/harishgokul/Finsights/backend/lib/python3.13/site-packages/google_crc32c/__init__.py:29: RuntimeWarning: As the c extension couldn't be imported, `google-crc32c` is using a pure python implementation that is significantly slower. If possible, please configure a c build environment and compile the extension
#   warnings.warn(_SLOW_CRC32C_WARNING, RuntimeWarning)
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/harishgokul/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/harishgokul/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!

# %%
class Settings(BaseSettings):
    env: str
    debug: bool
    llama_cloud_api_key: str
    groq_api_key: str
    google_api_key: str
    google_application_credentials: str 
    google_cloud_project: str

    class Config:
        env_file = ".env"
        
settings = Settings()
print(settings)
# Out:
# env='development' debug=True llama_cloud_api_key='llx-Xd3bToYQS8XAvHp3mXXOYjA9zpf03Pj4fVjUFZK7kNJ5wpla' groq_api_key='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' google_api_key='AIzaSyCMD3SFQuCKRzs8K-mCpAN96ef2fGl4eTc' google_application_credentials='planar-cistern-448818-f5-51aaa5a4c553.json' google_cloud_project='planar-cistern-448818-f5'

# %%
PROJECT_ID = "planar-cistern-448818-f5"  # @param {type:"string"}
REGION = "us-central1"  # @param {type:"string"}
if not PROJECT_ID.strip():
    raise ValueError("'PROJECT_ID' is required.")
if not REGION.strip():
    raise ValueError("'REGION' is required.")

import vertexai
vertexai.init(project=PROJECT_ID, location=REGION)

# %%
def pdf_to_markdown(file_name, output_dir="data") -> str:
    parser = LlamaParse(
        api_key=settings.llama_cloud_api_key,
        result_type="markdown",
        verbose=True,
    )
    
    input_path = os.path.join(output_dir, file_name)
    output_path = os.path.join(output_dir, file_name.replace(".pdf", ".md"))
    
    if os.path.exists(output_path):
        print(f"Markdown file already exists at: {output_path}")
        with open(output_path, "r", encoding="utf-8") as f:
            content = f.read()
        return content
    
    extra_info = {"file_name": file_name}
    
    with open(input_path, "rb") as f:
        documents = parser.load_data(f, extra_info=extra_info)
    
    content = "".join(doc.get_content() for doc in documents)
    
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(content)
    
    print(f"Markdown file saved at: {output_path}")
    return content

# %%
file_name = "us_bank"
pdf_file_name = f"{file_name}.pdf"
markdown_file_name = f"{file_name}.md"
content = pdf_to_markdown(file_name=pdf_file_name)
content
# Out:
# Markdown file already exists at: data/us_bank.md
# '# Business Statement\n\nAccount Number: 1 455 7029 8821\n\nP.O. Box 1800\n\nSaint Paul, Minnesota 55101-0800\n\nStatement Period: Oct 2, 2017 through Oct 31, 2017\n\nPage 1 of 8\n\n000007622 02 SP 106481289740840 S\n\n# BETHLEHEM HOME HEALTH CARE AGENCY\n\n2726 FOREST AVE\n\nKANSAS CITY MO 64109-1224\n\n# To Contact U.S. Bank\n\n24-Hour Business Solutions: 1-800-673-3555\n\nU.S. Bank accepts Relay Calls\n\nInternet: usbank.com\n\n# INFORMATION YOU SHOULD KNOW\n\nEffective November 13, 2017, the "Your Deposit Account Agreement" booklet includes a number of updates and may affect your rights. As of Nov. 13, 2017 you may pick up copies at your local branch or view copies at usbank.com, or call 1-800-USBANKS (1-800-872-2657) for a copy. Please see the Additional Information Section of this statement for the main updates that were made to "Your Deposit Account Agreement" booklet.\n\n# SILVER BUSINESS CHECKING\n\nMember FDIC\n\nAccount Number 1-455-7029-8821\n\n# U.S. Bank National Association\n\n# Account Summary\n\n| |# Items|Amount| | | |\n|---|---|---|---|---|---|\n|Beginning Balance on Oct 2|$ 10,487.68| | | | |\n|Other Deposits|17|$ 87,684.11| | | |\n|Card Withdrawals|5|-$ 586.27| | | |\n|Other Withdrawals|10|-$ 47,024.45| | | |\n|Checks Paid|29|-$ 30,416.69| | | |\n|Ending Balance on Oct 31, 2017|$ 20,144.38| | | | |\n\n# Other Deposits\n\n|Date|Description of Transaction|Ref Number|Amount|\n|---|---|---|---|\n|Oct 2|Electronic Deposit From 36 TREAS 310|REF=172750102657000N00|$ 7,265.00|\n|Oct 3|Electronic Deposit From 36 TREAS 310|REF=172760027363140N00|$ 6,400.00|\n|Oct 4|Electronic Deposit From CGS ADMINISTATOR|REF=172720058223180Y00|$ 11,911.98|\n|Oct 11|Electronic Deposit From CGS ADMINISTATOR|REF=172780042278970Y00|$ 4,972.84|\n|Oct 12|Electronic Deposit From 36 TREAS 310|REF=172850024413210N00|$ 4,510.00|\n|Oct 12|Electronic Deposit From CGS ADMINISTATOR|REF=172790122999750Y00|$ 5,597.43|\n|Oct 16|Electronic Deposit From 36 TREAS 310|REF=172890066691320N00|$ 2,641.08|\n|Oct 17|Electronic Deposit From CGS ADMINISTATOR|REF=172850047281610Y00|$ 3,036.78|\n|Oct 20|Electronic Deposit From 36 TREAS 310|REF=172920112272070N00|$ 760.00|\n|Oct 20|Electronic Deposit From CGS ADMINISTATOR|REF=172900111651190Y00|$ 11,414.48|\n|Oct 23|Electronic Deposit From 36 TREAS 310|REF=172960092179570N00|$ 3,150.00|\n|Oct 24|Electronic Deposit From CGS ADMINISTATOR|REF=172920071406510Y00|$ 305.71|\n|Oct 24|Electronic Deposit From 36 TREAS 310|REF=172960187647050N00|$ 660.00|\n|Oct 25|Electronic Deposit From CGS ADMINISTATOR|REF=172930041655740Y00|$ 11,572.01|# BALANCE YOUR ACCOUNT\n\nTo keep track of all your transactions, you should balance your account every month. Please examine this statement immediately. We will assume that the balance and transactions shown are correct unless you notify us of an error.\n\n# Outstanding Deposits\n\n|DATE|AMOUNT|\n|---|---|\n|1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total.|1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total.| |\n|TOTAL|$|\n\n# Outstanding Withdrawals\n\n|DATE|AMOUNT|\n|---|---|\n|2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total.|2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total.| |\n|3. Enter the ending balance shown on this statement.|3. Enter the ending balance shown on this statement.| |\n|4. Enter the total deposits recorded in the Outstanding Deposits section.|4. Enter the total deposits recorded ...

# %%
loader = UnstructuredMarkdownLoader(f"data/{markdown_file_name}")
markdown_document = loader.load()
headers_to_split_on = [("#", "Header 1"),("##", "Header 2"),("###", "Header 3")]

markdown_splitter = MarkdownHeaderTextSplitter(headers_to_split_on,strip_headers=False)
splits = markdown_splitter.split_text(markdown_document[0].page_content)
markdown_document[0].page_content
# Out:
# 'Business Statement\n\nAccount Number: 1 455 7029 8821\n\nP.O. Box 1800\n\nSaint Paul, Minnesota 55101-0800\n\nStatement Period: Oct 2, 2017 through Oct 31, 2017\n\nPage 1 of 8\n\n000007622 02 SP 106481289740840 S\n\nBETHLEHEM HOME HEALTH CARE AGENCY\n\n2726 FOREST AVE\n\nKANSAS CITY MO 64109-1224\n\nTo Contact U.S. Bank\n\n24-Hour Business Solutions: 1-800-673-3555\n\nU.S. Bank accepts Relay Calls\n\nInternet: usbank.com\n\nINFORMATION YOU SHOULD KNOW\n\nEffective November 13, 2017, the "Your Deposit Account Agreement" booklet includes a number of updates and may affect your rights. As of Nov. 13, 2017 you may pick up copies at your local branch or view copies at usbank.com, or call 1-800-USBANKS (1-800-872-2657) for a copy. Please see the Additional Information Section of this statement for the main updates that were made to "Your Deposit Account Agreement" booklet.\n\nSILVER BUSINESS CHECKING\n\nMember FDIC\n\nAccount Number 1-455-7029-8821\n\nU.S. Bank National Association\n\nAccount Summary\n\n# Items \n Amount \n \n \n \n \n Beginning Balance on Oct 2 \n $ 10,487.68 \n \n \n \n \n \n Other Deposits \n 17 \n $ 87,684.11 \n \n \n \n \n Card Withdrawals \n 5 \n -$ 586.27 \n \n \n \n \n Other Withdrawals \n 10 \n -$ 47,024.45 \n \n \n \n \n Checks Paid \n 29 \n -$ 30,416.69 \n \n \n \n \n Ending Balance on Oct 31, 2017 \n $ 20,144.38\n\nOther Deposits\n\nDate \n Description of Transaction \n Ref Number \n Amount \n \n Oct 2 \n Electronic Deposit From 36 TREAS 310 \n REF=172750102657000N00 \n $ 7,265.00 \n \n Oct 3 \n Electronic Deposit From 36 TREAS 310 \n REF=172760027363140N00 \n $ 6,400.00 \n \n Oct 4 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172720058223180Y00 \n $ 11,911.98 \n \n Oct 11 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172780042278970Y00 \n $ 4,972.84 \n \n Oct 12 \n Electronic Deposit From 36 TREAS 310 \n REF=172850024413210N00 \n $ 4,510.00 \n \n Oct 12 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172790122999750Y00 \n $ 5,597.43 \n \n Oct 16 \n Electronic Deposit From 36 TREAS 310 \n REF=172890066691320N00 \n $ 2,641.08 \n \n Oct 17 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172850047281610Y00 \n $ 3,036.78 \n \n Oct 20 \n Electronic Deposit From 36 TREAS 310 \n REF=172920112272070N00 \n $ 760.00 \n \n Oct 20 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172900111651190Y00 \n $ 11,414.48 \n \n Oct 23 \n Electronic Deposit From 36 TREAS 310 \n REF=172960092179570N00 \n $ 3,150.00 \n \n Oct 24 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172920071406510Y00 \n $ 305.71 \n \n Oct 24 \n Electronic Deposit From 36 TREAS 310 \n REF=172960187647050N00 \n $ 660.00 \n \n Oct 25 \n Electronic Deposit From CGS ADMINISTATOR \n REF=172930041655740Y00 \n $ 11,572.01\n\nTo keep track of all your transactions, you should balance your account every month. Please examine this statement immediately. We will assume that the balance and transactions shown are correct unless you notify us of an error.\n\nOutstanding Deposits\n\nDATE \n AMOUNT \n \n 1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total. \n 1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total. \n \n TOTAL \n $\n\nOutstanding Withdrawals\n\nDATE \n AMOUNT \n \n 2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total. \n 2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total. \n \n 3. Enter the ending balance shown on this statement. \n 3. Enter the ending ba ...

# %%
import pandas as pd
from collections import defaultdict
from tabulate import tabulate

reader = MarkdownTableTextLoader(text=content)

table_groups = defaultdict(list)

for table in reader.load():
    headers = tuple(table.headers)
    table_groups[headers].extend(table.rows)

dataframes = {headers: pd.DataFrame(rows, columns=headers) for headers, rows in table_groups.items()}

for headers, df in dataframes.items():
    print(f"Table with headers {headers}:")
    print(tabulate(df, headers='keys', tablefmt='pretty'))
# Out:
# Table with headers ('', '# Items', 'Amount', '', '', ''):
# +---+--------------------------------+-------------+--------------+--+--+--+
# |   |                                |   # Items   |    Amount    |  |  |  |
# +---+--------------------------------+-------------+--------------+--+--+--+
# | 0 |   Beginning Balance on Oct 2   | $ 10,487.68 |              |  |  |  |
# | 1 |         Other Deposits         |     17      | $ 87,684.11  |  |  |  |
# | 2 |        Card Withdrawals        |      5      |  -$ 586.27   |  |  |  |
# | 3 |       Other Withdrawals        |     10      | -$ 47,024.45 |  |  |  |
# | 4 |          Checks Paid           |     29      | -$ 30,416.69 |  |  |  |
# | 5 | Ending Balance on Oct 31, 2017 | $ 20,144.38 |              |  |  |  |
# +---+--------------------------------+-------------+--------------+--+--+--+
# Table with headers ('Date', 'Description of Transaction', 'Ref Number', 'Amount'):
# +----+--------+-----------------------------------------------------------------+-------------------------------+--------------+
# |    |  Date  |                   Description of Transaction                    |          Ref Number           |    Amount    |
# +----+--------+-----------------------------------------------------------------+-------------------------------+--------------+
# | 0  | Oct 2  |              Electronic Deposit From 36 TREAS 310               |    REF=172750102657000N00     |  $ 7,265.00  |
# | 1  | Oct 3  |              Electronic Deposit From 36 TREAS 310               |    REF=172760027363140N00     |  $ 6,400.00  |
# | 2  | Oct 4  |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172720058223180Y00     | $ 11,911.98  |
# | 3  | Oct 11 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172780042278970Y00     |  $ 4,972.84  |
# | 4  | Oct 12 |              Electronic Deposit From 36 TREAS 310               |    REF=172850024413210N00     |  $ 4,510.00  |
# | 5  | Oct 12 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172790122999750Y00     |  $ 5,597.43  |
# | 6  | Oct 16 |              Electronic Deposit From 36 TREAS 310               |    REF=172890066691320N00     |  $ 2,641.08  |
# | 7  | Oct 17 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172850047281610Y00     |  $ 3,036.78  |
# | 8  | Oct 20 |              Electronic Deposit From 36 TREAS 310               |    REF=172920112272070N00     |   $ 760.00   |
# | 9  | Oct 20 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172900111651190Y00     | $ 11,414.48  |
# | 10 | Oct 23 |              Electronic Deposit From 36 TREAS 310               |    REF=172960092179570N00     |  $ 3,150.00  |
# | 11 | Oct 24 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172920071406510Y00     |   $ 305.71   |
# | 12 | Oct 24 |              Electronic Deposit From 36 TREAS 310               |    REF=172960187647050N00     |   $ 660.00   |
# | 13 | Oct 25 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172930041655740Y00     | $ 11,572.01  |
# | 14 | Oct 27 |              Electronic Deposit From 36 TREAS 310               |    REF=173000029008250N00     |    360.00    |
# | 15 | Oct 27 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172970019287930Y00     |   5,819.54   |
# | 16 | Oct 31 |            Electronic Deposit From CGS ADMINISTATOR             |    REF=172990090266280Y00     |   7,307.26   |
# | 17 | Oct 2  |   Debit Purchase - VISA On 092917 MISSION KS PANERA BREAD #20   | REF # 24427337272720040130721 |   $ 7.00-    |
# | 18 | Oct 2  |   Debit Purchase - VISA On 092917 MISSION KS CHICK-FIL-A #029   | REF # 24427337273710023729507 |   $ 7.02-    |
# | 19 | Oct 4  | Debit Purchase - VISA On 100317 WWW.SOS.MO.G MO MO SEC OF STATE | REF # 24540457277235570575040 |   $ 51.25-   |
# | 20 | Oct 6  | Debit Purchase - VISA On 100517 800-5563012 KS FREDPRYOR CAREER | REF # 24906417278045224965328 |  $ 149.00-   |
# | 21 | Oct 10 | Debit Purchase - VISA On 100617 816-7638200 MO THE PLUMBING PRO | REF # 24183107279900014900051 |  $ 372.00-   |
# | 22 | Oct 6  |            Electronic Withdrawal To BlueKc Com Stlmt            |    REF=172780089093620N00     |  $ 195.34-   |
# | 23 | Oct 6  |                       Customer Withdrawal                       |                               |  $ 500.00-   |
# | 24 | Oct 12 |         Branch Account Transfer To Account 145574108240         |                               | $ 8,000.00-  |
# | 25 | Oct 12 |         Branch Account Transfer To Account 145570459670         |                               | $ 12,000.00- |
# | 26 | Oct 16 |             Electronic Withdrawal From PHILA INS CO             |    REF=172890065018750N00     |   $ 5.00-    |
# | 27 | Oct 16 |                     Analysis Service Charge                     |                               |   $ 24.95-   |
# | 28 | Oct 16 |             Electronic Withdrawal From PHILA INS CO             |    REF=172890065018740N00     | $ 7,514.68-  |
# | 29 | Oct 25 |                 Electronic Withdrawal From ATT                  |    REF=172970047495440N00     |  $ 308.48-   |
# | 30 | Oct 25 |         Branch Account Transfer To Account 145574108240         |                               | $ 7,700.00-  |
# | 31 | Oct 25 |         Branch Account Transfer To Account 145570459670         |                               | $ 10,776.00- |
# +----+--------+-----------------------------------------------------------------+-------------------------------+--------------+
# Table with headers ('DATE', 'AMOUNT'):
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |    |                                                                                                                                        DATE                                                                                                                                        |                                                                                                                                       AMOUNT                                                                                                                                       |
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# | 0  |                                                                            1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total.                                                                            |                                                                            1. List any deposits that do not appear on your statement in the Outstanding Deposits section at the left. Record the total.                                                                            |
# | 1  |                                                                                                                                       TOTAL                                                                                                                                        |                                                                                                                                         $                                                                                                                                          |
# | 2  | 2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total. | 2. Check off in your checkbook register all checks, withdrawals (including Debit Card and ATM) and automatic payments that appear on your statement. Withdrawals that are NOT checked off should be recorded in the Outstanding Withdrawals section at the left. Record the total. |
# | 3  |                                                                                                                3. Enter the ending balance shown on this statement.                                                                                                                |                                                                                                                3. Enter the ending balance shown on this statement.                                                                                                                |
# | 4  |                                                                                                     4. Enter the total deposits recorded in the Outstanding Deposits section.                                                                                                      |                                                                                                     4. Enter the total deposits recorded in the Outstanding Deposits section.                                                                                                      |
# | 5  |                                                                                                                              5. Total lines 3 and 4.                                                                                                                               |                                                                                                                              5. Total lines 3 and 4.                                                                                                                               |
# | 6  |                                                                                                  6. Enter the total withdrawals recorded in the Outstanding Withdrawals section.                                                                                                   |                                                                                                  6. Enter the total withdrawals recorded in the Outstanding Withdrawals section.                                                                                                   |
# | 7  |                                                                                                               7. Subtract line 6 from line 5. This is your balance.                                                                                                                |                                                                                                               7. Subtract line 6 from line 5. This is your balance.                                                                                                                |
# | 8  |                                   8. Enter in your register and subtract from your register balance any checks, withdrawals or other debits (including fees, if any) that appear on your statement but have not been recorded in your register.                                    |                                   8. Enter in your register and subtract from your register balance any checks, withdrawals or other debits (including fees, if any) that appear on your statement but have not been recorded in your register.                                    |
# | 9  |                                          9. Enter in your register and add to your register balance any deposits or other credits (including interest, if any) that appear in your statement but have not been recorded in your register.                                          |                                          9. Enter in your register and add to your register balance any deposits or other credits (including interest, if any) that appear in your statement but have not been recorded in your register.                                          |
# | 10 |     10. The balance in your register should be the same as the balance shown in #7. If it does not match, review and check all figures used, and check the addition and subtraction in your register. If necessary, review and balance your statement from the previous month.     |     10. The balance in your register should be the same as the balance shown in #7. If it does not match, review and check all figures used, and check the addition and subtraction in your register. If necessary, review and balance your statement from the previous month.     |
# | 11 |                                                                                                                                       TOTAL                                                                                                                                        |                                                                                                                                         $                                                                                                                                          |
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# Table with headers ('Check', 'Date', 'Ref Number', 'Amount', 'Check', 'Date', 'Ref Number', 'Amount'):
# +----+-------+--------+------------+----------+-------+--------+------------+----------+
# |    | Check |  Date  | Ref Number |  Amount  | Check |  Date  | Ref Number |  Amount  |
# +----+-------+--------+------------+----------+-------+--------+------------+----------+
# | 0  | 4667  | Oct 16 | 8054899793 | 3,777.34 | 4676  | Oct 11 | 8653152613 | 2,500.00 |
# | 1  | 4670* | Oct 2  | 8058398645 | 1,146.08 | 4677  | Oct 17 | 8357222187 |  320.00  |
# | 2  | 4671  | Oct 10 | 8355786671 | 1,146.08 | 4678  | Oct 6  | 9255287389 |  228.00  |
# | 3  | 4672  | Oct 2  | 8059110408 |  70.00   | 4679  | Oct 11 | 8658208621 |  754.99  |
# | 4  | 4675* | Oct 11 | 8656387853 |  200.00  | 4680  | Oct 16 | 8058344405 |  33.23   |
# | 5  | 4681  | Oct 27 | 9254685896 |  425.71  | 4695  | Oct 16 | 8055343884 | 3,341.36 |
# | 6  | 4682  | Oct 6  | 9250487356 | 1,804.60 | 4696  | Oct 16 | 8055343900 |  118.50  |
# | 7  | 4683  | Oct 4  | 8655296985 | 3,000.00 | 4697  | Oct 17 | 8356666578 |  78.65   |
# | 8  | 4685* | Oct 10 | 8450678071 |  379.26  | 4698  | Oct 16 | 8057502145 |  195.06  |
# | 9  | 4687* | Oct 20 | 9254033749 |  287.66  | 4699  | Oct 13 | 9255096967 |  450.00  |
# | 10 | 4690* | Oct 19 | 8953131485 |  995.00  | 4701* | Oct 17 | 8357222186 |  320.00  |
# | 11 | 4691  | Oct 19 | 8954261559 |  34.55   | 4702  | Oct 26 | 8953683904 | 1,706.25 |
# | 12 | 4692  | Oct 17 | 8357163065 |  726.37  | 4705* | Oct 27 | 9254620542 |  168.00  |
# | 13 | 4693  | Oct 17 | 8357515837 |  110.00  | 4706  | Oct 31 | 8357136962 | 6,000.00 |
# | 14 | 4694  | Oct 26 | 8954464706 |  100.00  |       |        |            |          |
# +----+-------+--------+------------+----------+-------+--------+------------+----------+
# Table with headers ('Date', 'Ending Balance', 'Date', 'Ending Balance', 'Date', 'Ending Balance'):
# +---+--------+----------------+--------+----------------+--------+----------------+
# |   |  Date  | Ending Balance |  Date  | Ending Balance |  Date  | Ending Balance |
# +---+--------+----------------+--------+----------------+--------+----------------+
# | 0 | Oct 2  |   16,522.58    | Oct 12 |   18,634.31    | Oct 23 |   21,304.30    |
# | 1 | Oct 3  |   22,922.58    | Oct 13 |   18,184.31    | Oct 24 |   22,270.01    |
# | 2 | Oct 4  |   31,783.31    | Oct 16 |    5,815.27    | Oct 25 |   15,057.54    |
# | 3 | Oct 6  |   28,906.37    | Oct 17 |    7,297.03    | Oct 26 |   13,251.29    |
# | 4 | Oct 10 |   27,009.03    | Oct 19 |    6,267.48    | Oct 27 |   18,837.12    |
# | 5 | Oct 11 |   28,526.88    | Oct 20 |   18,154.30    | Oct 31 |   20,144.38    |
# +---+--------+----------------+--------+----------------+--------+----------------+
# Table with headers ('Service', 'Volume', 'Avg Unit Price', 'Total Charge'):
# +---+---------------------+-------------------------------+----------------+--------------+
# |   |       Service       |            Volume             | Avg Unit Price | Total Charge |
# +---+---------------------+-------------------------------+----------------+--------------+
# | 0 | Depository Services |  Combined Transactions/Items  |       54       |  No Charge   |
# | 1 |                     | Subtotal: Depository Services |                |     0.00     |
# | 2 |     SinglePoint     |  SPE Pday Det & Sum Mo Maint  |       2        |   7.47500    |
# | 3 |                     | SPE Previous Day per Item Det |      103       |  No Charge   |
# | 4 |                     |     SPE Acct Analysis PDF     |       1        |   10.00000   |
# | 5 |                     |     Subtotal: SinglePoint     |                |    24.95     |
# | 6 |   Image Services    |      SPE Image Retrieved      |       29       |  No Charge   |
# | 7 |                     |   Subtotal: Image Services    |                |     0.00     |
# | 8 |    ACH Services     |   ACH Received Addenda Item   |      382       |  No Charge   |
# | 9 |                     |    Subtotal: ACH Services     |                |     0.00     |
# +---+---------------------+-------------------------------+----------------+--------------+
# Table with headers ('DOLLARS', 'DATE', 'BETHLEHEM HEALTH CARE', 'ACCOUNT NUMBER', 'AMOUNT', 'KANSAS CITY, MO 64109'):
# +---+----------+--------+-----------------------+----------------+----------+-----------------------+
# |   | DOLLARS  |  DATE  | BETHLEHEM HEALTH CARE | ACCOUNT NUMBER |  AMOUNT  | KANSAS CITY, MO 64109 |
# +---+----------+--------+-----------------------+----------------+----------+-----------------------+
# | 0 |  500.00  | Oct 06 |         4672          |  145570278821  |  70.00   |      2726 AVENUE      |
# | 1 | 3,727.00 | Oct 02 |         4667          |  145570298821  |  200.00  |                       |
# | 2 | 3,777.34 | Oct 11 |         4675          |                | 2,500.00 |                       |
# | 3 | 1,146.08 | Oct 02 |         4670          |                |  320.00  |                       |
# | 4 | 1,146.08 | Oct 10 |         4671          |                |          |                       |
# +---+----------+--------+-----------------------+----------------+----------+-----------------------+
# Table with headers ('DATE', 'CHECK NUMBER', 'AMOUNT'):
# +---+--------+--------------+----------+
# |   |  DATE  | CHECK NUMBER |  AMOUNT  |
# +---+--------+--------------+----------+
# | 0 | Oct 06 |     4678     |  228.00  |
# | 1 | Oct 06 |     4682     | 1,804.60 |
# | 2 | Oct 11 |     4679     |  754.99  |
# | 3 | Oct 04 |     4683     | 3,000.00 |
# | 4 | Oct 16 |     4680     |  33.23   |
# | 5 | Oct 10 |     4685     |  379.26  |
# | 6 | Oct 27 |     4681     |  425.71  |
# | 7 | Oct 20 |     4687     |  287.66  |
# +---+--------+--------------+----------+
# Table with headers ('DATE', 'PAY', 'DOLLARS'):
# +---+--------+----------+---------+
# |   |  DATE  |   PAY    | DOLLARS |
# +---+--------+----------+---------+
# | 0 | Oct 19 |  100.00  |  4694   |
# | 1 | Oct 19 |  34.55   |  4695   |
# | 2 | Oct 17 |  726.37  |  4696   |
# | 3 | Oct 17 |  110.00  |  4697   |
# | 4 | Oct 16 | 3,341.36 |  4695   |
# | 5 | Oct 16 |  118.50  |  4696   |
# +---+--------+----------+---------+
# Table with headers ('Check Number', 'Date', 'Amount'):
# +---+--------------+--------+----------+
# |   | Check Number |  Date  |  Amount  |
# +---+--------------+--------+----------+
# | 0 |     4698     | Oct 16 |  195.06  |
# | 1 |     4699     | Oct 13 |  450.00  |
# | 2 |    4701*     | Oct 17 |  320.00  |
# | 3 |     4702     | Oct 26 | 1,706.25 |
# | 4 |    4705*     | Oct 27 |  168.00  |
# | 5 |     4706     | Oct 31 | 6,000.00 |
# +---+--------------+--------+----------+

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader(pdf_file_name)
pages = loader.load_and_split()
docs = pages
docs

# %%
from langchain_google_vertexai import VertexAIEmbeddings 

def get_store(docs) -> tuple[FastEmbedEmbeddings,Chroma]:
    model = VertexAIEmbeddings(model="text-embedding-005")
    #model = FastEmbedEmbeddings(model_name="BAAI/bge-base-en-v1.5")
    store = Chroma.from_documents(
        documents=docs,
        embedding=model,
        collection_name="rag"
    )
    print('Vector DB created successfully !')
    return (store,model)

# %%
store,model = get_store(splits)
# Out:
# Vector DB created successfully !

# %%
#chat_model = ChatGroq(temperature=0.6,model_name="llama-3.3-70b-versatile",api_key=settings.groq_api_key)
chat_model = ChatVertexAI(model_name="gemini-2.0-flash-exp",project="planar-cistern-448818-f5",temperature=0)

# %%
vectorstore = Chroma(embedding_function=model,
                      collection_name="rag")

retriever=vectorstore.as_retriever()

# %%
custom_prompt_template = """Use the following pieces of information to answer the user's question.
If you don't know the answer, just say that you don't know, don't try to make up an answer.

Context: {context}
Question: {question}

Only return the helpful answer below and nothing else.
Helpful answer:
"""

# %%
def set_custom_prompt():
    """
    Prompt template for QA retrieval for each vectorstore
    """
    prompt = PromptTemplate(template=custom_prompt_template,
                            input_variables=['context', 'question'])
    return prompt

prompt = set_custom_prompt()
prompt
# Out:
# PromptTemplate(input_variables=['context', 'question'], input_types={}, partial_variables={}, template="Use the following pieces of information to answer the user's question.\nIf you don't know the answer, just say that you don't know, don't try to make up an answer.\n\nContext: {context}\nQuestion: {question}\n\nOnly return the helpful answer below and nothing else.\nHelpful answer:\n")

# %%
qa = RetrievalQA.from_chain_type(llm=chat_model,
                               chain_type="stuff",
                               retriever=retriever,
                               return_source_documents=True,
                               chain_type_kwargs={"prompt": prompt})

# %%
from langchain_core.documents import Document
response = qa.invoke({"query": "what is the opening balance"})
response
# Out:
# Number of requested results 4 is greater than number of elements in index 2, updating n_results = 2
# {'query': 'what is the opening balance',
#  'result': 'The opening balance for the Commonwealth Bank account is $2,217.29 CR, and the opening balance for the Lloyds Bank account is £1173.56.\n',
#  'source_documents': [Document(metadata={}, page_content="Commonwealth Bank  \nYour Statement  \nCommonwealth Bank of Australia  \nABN 48 123 123 124  \nAFSL and Australian credit licence 234945  \nStatement 29 (Page 1 of 3)  \nAccount Number: 06 6104 10252276  \nMR C H BENNISON  \nPeriod: 14 Oct 2017 - 13 Jan 2018  \nClosing Balance: $395.43 CR  \nEnquiries: 13 2221 (24 hours a day, 7 days a week)  \nSmart Access  \nEnjoy the convenience and security of withdrawing what you need, when you need it. Plus you can have your monthly account fee waived if you deposit at least $2,000 each calendar month.  \nName: CLIFFORD HENRY BENNISON  \nNote: Have you checked your statement today? It's easy to find out more information about each of your transactions by logging on to the CommBank App or NetBank. Should you have any questions on fees or see an error please contact us on the details above. Cheque proceeds are available when cleared.  \nDate\nTransaction\nDebit\nCredit\nBalance  \n14 Oct 2017\nOPENING BALANCE  \n$2,217.29 CR  \n15 Oct\nAlinta Sales Pty Ltd NetBank BPAY 2733 0400032246\n50.00  \n$2,167.29 CR  \n23 Oct\nVIRGIN MONEY NetBank BPAY 49551 4724373501635385\n1,000.00  \n$1,167.29 CR  \n23 Oct\nTransfer to xx6832 NetBank\n70.00  \n$1,097.29 CR  \n23 Oct\nDirect Debit 180247 SGIO MOT563142623171021\n56.42  \n$1,040.87 CR  \n26 Oct\nDirect Debit 165969 JETTS KINGSWAY 201724473788\n27.90  \n$1,012.97 CR  \n01 Nov\nAccount Fee\n4.00  \n$1,008.97 CR  \n01 Nov\nDirect Credit 421520 JESSICA LAING JL - Internet  \n40.00\n$1,048.97 CR  \n01 Nov\nTransfer from xx8727 CommBank app  \n1,000.00\n$2,048.97 CR  \n01 Nov\nDirect Debit 000702 HBF - HEALTH 1439123504\n122.25  \n$1,926.72 CR  \n05 Nov\nTransfer to other Bank NetBank Oronsay\n700.00  \n$1,226.72 CR  \n07 Nov\nTELSTRA CORP LTD NetBank BPAY 23796 2000353972134\n115.00  \n$1,111.72 CR  \n09 Nov\nDirect Debit 165969 JETTS KINGSWAY 201725516901\n27.90  \n$1,083.82 CR  \n21 Nov\nDirect Debit 180247 SGIO MOT563142623171121\n56.42  \n$1,027.40 CR  \n22 Nov\nDirect Debit 068093 SYNERGY RETAIL B 257300733078\n190.70  \n$836.70 CR  \n23 Nov\nDirect Debit 165969 JETTS KINGSWAY 201726554790\n27.90  \n$808.80 CR  \nAccount Number 06 6104 10252276  \nDate\nTransaction\nDebit\nCredit\nBalance  \n01 Dec\nAccount Fee\n4.00  \n$804.80 CR  \n01 Dec\nDirect Credit 421520 JESSICA LAING JL - Internet  \n40.00\n$844.80 CR  \n01 Dec\nTransfer from xx8727 NetBank  \n1,000.00\n$1,844.80 CR  \n01 Dec\nTransfer to xx6832 NetBank\n70.00  \n$1,774.80 CR  \n01 Dec\nDirect Debit 000702 HBF - HEALTH 1439123504\n122.25  \n$1,652.55 CR  \n05 Dec\nTransfer to other Bank NetBank Oronsay\n700.00  \n$952.55 CR  \n06 Dec\nTAX OFFICE PAYMENTS NetBank BPAY 75556 551004045508468221 ATO tax 2016 to 20\n850.75  \n$101.80 CR  \n06 Dec\nTransfer from xx8727 NetBank  \n700.00\n$801.80 CR  \n07 Dec\nTELSTRA CORP LTD NetBank BPAY 23796 2000353972134\n115.00  \n$686.80 CR  \n07 Dec\nDirect Debit 165969 JETTS KINGSWAY 201727539277\n27.90  \n$658.90 CR  \n21 Dec\nDirect Debit 180247 SGIO MOT563142623171221\n56.42  \n$602.48 CR  \n21 Dec\nDirect Debit 165969 JETTS KINGSWAY 201728541361\n27.90  \n$574.58 CR  \n27 Dec\nDirect Credit 106600 CAMERON BROWNING Ool party thanks x  \n20.00\n$594.58 CR  \n01 Jan\nAccount Fee\n4.00  \n$590.58 CR  \n02 Jan\nDirect Credit 421520 JESSICA LAING JL - Internet  \n40.00\n$630.58 CR  \n02 Jan\nDirect Debit 000702 HBF - HEALTH 1439123504\n122.25  \n$508.33 CR  \n04 Jan\nTransfer from xx8727 CommBank app  \n800.00\n$1,308.33 CR  \n04 Jan\nTransfer to xx6832 CommBank app\n70.00  \n$1,238.33 CR  \n04 Jan\nDirect Debit 165969 JETTS KINGSWAY 2018270979\n27.90  \n$1,210.43 CR  \n05 Jan\nTransfer to other Bank NetBank Oronsay\n700.00  \n$510.43 CR  \n07 Jan\nTELSTRA CORP LTD NetBank BPAY 23796 2000353972134\n115.00  \n$395.43 CR  \n13 Jan\n2018 CLOSING BALANCE  \n$395.43 CR  \nOpening balance\n-\nTotal debits\n+\nTotal credits\n=\nClosing balance  \n$2,217.29 CR  \n$5,461.86  \n$3,640.00  \n$395.43 CR  \nAc ...
#   Document(metadata={}, page_content="LLOYDS BANK  \nClassic statement  \n01 September 2019 to 30 November 2019  \nOleh Beshleu  \nSort code: 11-10-51  \n293 STRONE ROAD  \nMANOR PARK(BARKING AND DAGENHAM)  \nLONDON  \nE12 6TR  \nBIC: LOYDGB21033  \nAccount number: 45201526  \nIBAN: GB17LOYD30135525281061  \nMoney In\n£5420.12\nBalance on 01 September 2019\n£1173.56  \nMoney Out\n£3801.48\nBalance on 30 November 2019\n£2062.05  \nDate\nDescription\nType\nIn (£)\nOut (£)\nBalance (£)  \n04 Sep19\nLNK COOPERATIVE SW CD 4821 08DEC19\nCPT\n300.00  \n873.56  \n09 Sep19\nP ADAMCZUK KASA 7420\nTFR\n50.00  \n923.56  \n11 Sep19\nBARCLAYCARD CD 7420\nDEB  \n2.50\n921.06  \n15 Sep19\nWESTERN VILLA CD 7420\nDEB  \n240.00\n681.06  \n16 Sep19\nWINELEAF CD 7420\nDEB  \n26.69\n654.37  \n17 Sep19\nLNK COOPERATIVE SW CD 7420 06DEC19\nCPT\n200.00  \n454.37  \n18 Sep19\nLV LIFE 03592291015W\nDD  \n33.03\n421.34  \n22 Sep19\nPARK FOOD AND WINE CD 7420\nDEB  \n30.46\n390.88  \n22 Sep19\nLNK COOPERATIVE SW CD 7420 05DEC19\nCPT\n20.00  \n370.88  \n25 Sep19\nLNK COOPERATIVE SW CD 7420 03DEC19\nCPT\n200.00  \n170.88  \n26 Sep19\nUBER *TRIP LJSAM\nDEB  \n17.43\n153.45  \n29 Sep19\nD ROBERTSON\nDEB\n960.00  \n1113.45  \n03 Oct 19\nWINELEAF CD 7420\nDEB  \n17.00\n1096.45  \n05 Oct 19\nKATE EYR G D LTD KEGD\nFPI\n790.00  \n1886.45  \n08 Oct19\nLNK COOPERATIVE SW CD 7420 01DEC19\nCPT\n100.00  \n1786.45  \n12 Oct19\nLNK PO MITCHAM LAN CD 7420 30NOV19\nCPT\n10.00  \n1776.45  \n12 Oct 19\nMIS BAR MLECZNY CD 7420\nDEB  \n28.90\n1747.55  \n16 Oct 19\nSPORTSDIRECT 252 CD 7420\nDEB  \n27.99\n1719.56  \n19 Oct 19\nKATE EYR G D LTD KEGD\nFPI\n860.00  \n1849.56  \n22 Oct 19\nLOYD STREATHAM HIG\nCSH\n730.00  \n2579.56  \n23 Oct19\nA FARAFOSZYN\nTFR\n100.00  \n2479.56  \n23 Oct 19  \nWINELEAF CD 7420\nDEB\n10.50\n2469.06  \n24 Oct 19\nLNK PO MITCHAM LAN CD 7420 11SEP15\nCPT\n150.00\n2319.06  \n27 Oct 19\nMCDONALDS CD7420\nDEB\n25.79\n2293.67  \n30 Oct 19\nSUPER CHOICE CD 7420\nDEB\n76.60\n2216.67  \n05 Nov 19\nTESCO STORES 6765 CD 7420\nDEB\n42.60\n2174.07  \n06 Nov 19\nCROY CTRL 773001\nDEB\n200.12\n2374.07  \n07 Nov 19\nVODAFONE LTD 7014378191-1001\nDD\n50.00\n2324.07  \n11 Nov 19\nLOYD ROYDON CENTR CD 7420\nCPT\n200.00\n2124.07  \n13 Nov 19\nNIKE FACTORY STORE CD 7420\nDEB\n250.00\n1874.07  \n13 Nov 19\nLOYD STREATHAM HIG\nCSH\n340.00\n1534.04  \n14 Nov 19\n.$7( (<5 * ' /7' .(*'\n)3,\n870.00\n2404.04  \n17 Nov 19\nKINGS TUN CD 7420\nDEB\n56.60\n2347.44  \n18 Nov 19\nLNK COOPERATIVE SW CD 7420 17NOV19\nCPT\n170.00\n2177.44  \n19 Nov 19\nWESTERN VILLA CD7420\nDEB\n185.60\n1991.84  \n19 Nov 19\nP ADAMCZUK KASA\nTFR\n210.00\n1781.84  \n22 Nov 19\nBEDFORD TAVERN CD 7420\nDEB\n198.00\n1583.84  \n23 Nov 19\nMCDONALDS DC 7420\nDEB\n16.34\n1567.05  \n26 Nov 19\nKATE EYR G D LTD KEGD\nFPI\n960.00\n2527.05  \n27 Nov 19\nLNK WEST NORWOOD 1 CD 7420 27NOV19\nCPT\n70.00\n2457.05  \n28 Nov 19\nDELIGHT CD 7420\nDEB\n133.45\n2324.05  \n29 Nov 19\nAmazon UK Marketpl CD 7420\nDEB\n262.00\n2062.05  \nLloyds Bank plc Registered Office: 25 Gresham Street, London EC2V 7HN. Registered in England and Wales No: 2065.  \nAuthorised by the Prudential Regulation Authority and regulated by the Financial Conduct Authority and the Prudential Regulation Authority, under registration number 119278.  \nEligible deposits with us are protected by the Financial Services Compensation Scheme (FSCS). We are covered by the Financial Ombudsman Service(FOS). Please note that due to FSCS and FOS eligibility criteria not all business customers will be covered. For further information about the compensation provided by the FSCS, refer to the website at www.FSCS.org.uk.  \nhttps://secure.lloydsbank.co.uk/personal/a/viewproductdetails/printfriendlystatement.jsp")]}

# %%
import gradio as gr

def chat(question):
    response = qa.invoke({"query": question})
    answer = response["result"]
    sources = "\n".join(doc.page_content for doc in response["source_documents"])
    return f"**Answer:** {answer}\n\n"

# Gradio chatbot UI
chatbot = gr.Interface(
    fn=chat,
    inputs=gr.Textbox(placeholder="Ask me anything..."),
    outputs="markdown",
    title="RetrievalQA Chatbot",
    description="A chatbot powered by RetrievalQA. Ask a question and get relevant answers!",
)

iface = gr.ChatInterface(fn=chatbot, title="Finsights Chatbot")
iface.launch()
# Out:
# /Users/harishgokul/Finsights/lib/python3.13/site-packages/gradio/components/chatbot.py:288: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1

# %%
response["result"]
# Out:
# 'The bank statement shows a total debit of ₹1,69,717.26 and a total credit of ₹1,69,740.76, resulting in a closing balance of ₹45.12. The account is in a very small credit balance. The statement period is from 01-Apr-2018 to 31-Mar-2019. The statement shows that the customer has been very active in the account and has made numerous transactions.  \n'

# %%
# %pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in ./lib/python3.13/site-packages (2.2.3)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp313-cp313-macosx_10_13_x86_64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.26.0 in ./lib/python3.13/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.13/site-packages (from pandas) (2025.1)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.1-cp313-cp313-macosx_14_0_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: joblib>=1.2.0 in ./lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in ./lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading scikit_learn-1.6.1-cp313-cp313-macosx_10_13_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 2.7 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.15.1-cp313-cp313-macosx_14_0_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 5.9 MB/s eta 0:00:0000:0100:01
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.6.1 scipy-1.15.1 threadpoolctl-3.5.0
#
# [notice] A new release of pip is available: 24.2 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Example headers from two tables
headers_list = [
    ['Date', 'Description', 'Type', 'In (£)', 'Out (£)', 'Balance (£)'],
    ['Date', 'Description', 'Type', 'Debit', 'Credit', 'Balance']
]

# Standardized schema
standard_schema = ['Date', 'Transaction', 'Type', 'Debit', 'Credit', 'Balance']

# Flatten the headers and remove duplicates
all_headers = list(set(sum(headers_list, [])))

# Combine all headers with standard schema for vectorization
combined_headers = all_headers + standard_schema

# Convert headers into TF-IDF vectors
vectorizer = TfidfVectorizer().fit_transform(combined_headers)
vectors = vectorizer.toarray()

# Separate vectors for original headers and standard schema
original_vectors = vectors[:len(all_headers)]
standard_vectors = vectors[len(all_headers):]

# Compute cosine similarity
similarity_matrix = cosine_similarity(original_vectors, standard_vectors)

# Mapping headers to standardized schema
header_mapping = {}
for idx, header in enumerate(all_headers):
    most_similar_index = similarity_matrix[idx].argmax()
    header_mapping[header] = standard_schema[most_similar_index]

# Output the mapping as a JSON-like dictionary
print(header_mapping)
# Out:
# {'Credit': 'Credit', 'Balance (£)': 'Balance', 'In (£)': 'Date', 'Description': 'Date', 'Debit': 'Debit', 'Out (£)': 'Date', 'Type': 'Type', 'Balance': 'Balance', 'Date': 'Date'}

# %%
markdown_table_data = """ 
+----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
|    | id |    date     |                                 transaction                                 |  Debit   |  Credit  |   Balance    |
+----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
| 0  | 1  | 14 Oct 2017 |                               OPENING BALANCE                               |          |          | $2,217.29 CR |
| 1  | 2  |   15 Oct    |              Alinta Sales Pty Ltd NetBank BPAY 2733 0400032246              |  50.00   |          | $2,167.29 CR |
| 2  | 3  |   23 Oct    |              VIRGIN MONEY NetBank BPAY 49551 4724373501635385               | 1,000.00 |          | $1,167.29 CR |
| 3  | 4  |   23 Oct    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,097.29 CR |
| 4  | 5  |   23 Oct    |                 Direct Debit 180247 SGIO MOT563142623171021                 |  56.42   |          | $1,040.87 CR |
| 5  | 6  |   26 Oct    |               Direct Debit 165969 JETTS KINGSWAY 201724473788               |  27.90   |          | $1,012.97 CR |
| 6  | 7  |   01 Nov    |                                 Account Fee                                 |   4.00   |          | $1,008.97 CR |
| 7  | 8  |   01 Nov    |              Direct Credit 421520 JESSICA LAING JL - Internet               |          |  40.00   | $1,048.97 CR |
| 8  | 9  |   01 Nov    |                      Transfer from xx8727 CommBank app                      |          | 1,000.00 | $2,048.97 CR |
| 9  | 10 |   01 Nov    |                 Direct Debit 000702 HBF - HEALTH 1439123504                 |  122.25  |          | $1,926.72 CR |
| 10 | 11 |   05 Nov    |                   Transfer to other Bank NetBank Oronsay                    |  700.00  |          | $1,226.72 CR |
| 11 | 12 |   07 Nov    |              TELSTRA CORP LTD NetBank BPAY 23796 2000353972134              |  115.00  |          | $1,111.72 CR |
| 12 | 13 |   09 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201725516901               |  27.90   |          | $1,083.82 CR |
| 13 | 14 |   21 Nov    |                 Direct Debit 180247 SGIO MOT563142623171121                 |  56.42   |          | $1,027.40 CR |
| 14 | 15 |   22 Nov    |              Direct Debit 068093 SYNERGY RETAIL B 257300733078              |  190.70  |          |  $836.70 CR  |
| 15 | 16 |   23 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201726554790               |  27.90   |          |  $808.80 CR  |
| 16 | 17 |   01 Dec    |                                 Account Fee                                 |   4.00   |          |  $804.80 CR  |
| 17 | 18 |   01 Dec    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $844.80 CR  |
| 18 | 19 |   01 Dec    |                        Transfer from xx8727 NetBank                         |          | 1,000.00 | $1,844.80 CR |
| 19 | 20 |   01 Dec    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,774.80 CR |
| 20 | 21 |   01 Dec    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          | $1,652.55 CR |
| 21 | 22 |   05 Dec    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $952.55 CR  |
| 22 | 23 |   06 Dec    | TAX OFFICE PAYMENTS NetBank BPAY 75556551004045508468221 ATO tax 2016 to 20 |  850.75  |          |  $101.80 CR  |
| 23 | 24 |   06 Dec    |                        Transfer from xx8727 NetBank                         |          |  700.00  |  $801.80 CR  |
| 24 | 25 |   07 Dec    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $686.80 CR  |
| 25 | 26 |   07 Dec    |               Direct Debit 165969 JETTS KINGSWAY201727539277                |  27.90   |          |  $658.90 CR  |
| 26 | 27 |   21 Dec    |                 Direct Debit 180247 SGIOMOT563142623171221                  |  56.42   |          |  $602.48 CR  |
| 27 | 28 |   21 Dec    |               Direct Debit 165969 JETTS KINGSWAY201728541361                |  27.90   |          |  $574.58 CR  |
| 28 | 29 |   27 Dec    |           Direct Credit 106600 CAMERON BROWNINGOol party thanks x           |          |  20.00   |  $594.58 CR  |
| 29 | 30 |   01 Jan    |                                 Account Fee                                 |   4.00   |          |  $590.58 CR  |
| 30 | 31 |   02 Jan    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $630.58 CR  |
| 31 | 32 |   02 Jan    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          |  $508.33 CR  |
| 32 | 33 |   04 Jan    |                      Transfer from xx8727 CommBank app                      |          |  800.00  | $1,308.33 CR |
| 33 | 34 |   04 Jan    |                       Transfer to xx6832 CommBank app                       |  70.00   |          | $1,238.33 CR |
| 34 | 35 |   04 Jan    |                Direct Debit 165969 JETTS KINGSWAY2018270979                 |  27.90   |          | $1,210.43 CR |
| 35 | 36 |   05 Jan    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $510.43 CR  |
| 36 | 37 |   07 Jan    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $395.43 CR  |
| 37 | 38 | 13 Jan 2018 |                               CLOSING BALANCE                               |          |          |  $395.43 CR  |
+----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
"""
        
print(markdown_table_data)
# Out:
#
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
# |    | id |    date     |                                 transaction                                 |  Debit   |  Credit  |   Balance    |
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
# | 0  | 1  | 14 Oct 2017 |                               OPENING BALANCE                               |          |          | $2,217.29 CR |
# | 1  | 2  |   15 Oct    |              Alinta Sales Pty Ltd NetBank BPAY 2733 0400032246              |  50.00   |          | $2,167.29 CR |
# | 2  | 3  |   23 Oct    |              VIRGIN MONEY NetBank BPAY 49551 4724373501635385               | 1,000.00 |          | $1,167.29 CR |
# | 3  | 4  |   23 Oct    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,097.29 CR |
# | 4  | 5  |   23 Oct    |                 Direct Debit 180247 SGIO MOT563142623171021                 |  56.42   |          | $1,040.87 CR |
# | 5  | 6  |   26 Oct    |               Direct Debit 165969 JETTS KINGSWAY 201724473788               |  27.90   |          | $1,012.97 CR |
# | 6  | 7  |   01 Nov    |                                 Account Fee                                 |   4.00   |          | $1,008.97 CR |
# | 7  | 8  |   01 Nov    |              Direct Credit 421520 JESSICA LAING JL - Internet               |          |  40.00   | $1,048.97 CR |
# | 8  | 9  |   01 Nov    |                      Transfer from xx8727 CommBank app                      |          | 1,000.00 | $2,048.97 CR |
# | 9  | 10 |   01 Nov    |                 Direct Debit 000702 HBF - HEALTH 1439123504                 |  122.25  |          | $1,926.72 CR |
# | 10 | 11 |   05 Nov    |                   Transfer to other Bank NetBank Oronsay                    |  700.00  |          | $1,226.72 CR |
# | 11 | 12 |   07 Nov    |              TELSTRA CORP LTD NetBank BPAY 23796 2000353972134              |  115.00  |          | $1,111.72 CR |
# | 12 | 13 |   09 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201725516901               |  27.90   |          | $1,083.82 CR |
# | 13 | 14 |   21 Nov    |                 Direct Debit 180247 SGIO MOT563142623171121                 |  56.42   |          | $1,027.40 CR |
# | 14 | 15 |   22 Nov    |              Direct Debit 068093 SYNERGY RETAIL B 257300733078              |  190.70  |          |  $836.70 CR  |
# | 15 | 16 |   23 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201726554790               |  27.90   |          |  $808.80 CR  |
# | 16 | 17 |   01 Dec    |                                 Account Fee                                 |   4.00   |          |  $804.80 CR  |
# | 17 | 18 |   01 Dec    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $844.80 CR  |
# | 18 | 19 |   01 Dec    |                        Transfer from xx8727 NetBank                         |          | 1,000.00 | $1,844.80 CR |
# | 19 | 20 |   01 Dec    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,774.80 CR |
# | 20 | 21 |   01 Dec    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          | $1,652.55 CR |
# | 21 | 22 |   05 Dec    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $952.55 CR  |
# | 22 | 23 |   06 Dec    | TAX OFFICE PAYMENTS NetBank BPAY 75556551004045508468221 ATO tax 2016 to 20 |  850.75  |          |  $101.80 CR  |
# | 23 | 24 |   06 Dec    |                        Transfer from xx8727 NetBank                         |          |  700.00  |  $801.80 CR  |
# | 24 | 25 |   07 Dec    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $686.80 CR  |
# | 25 | 26 |   07 Dec    |               Direct Debit 165969 JETTS KINGSWAY201727539277                |  27.90   |          |  $658.90 CR  |
# | 26 | 27 |   21 Dec    |                 Direct Debit 180247 SGIOMOT563142623171221                  |  56.42   |          |  $602.48 CR  |
# | 27 | 28 |   21 Dec    |               Direct Debit 165969 JETTS KINGSWAY201728541361                |  27.90   |          |  $574.58 CR  |
# | 28 | 29 |   27 Dec    |           Direct Credit 106600 CAMERON BROWNINGOol party thanks x           |          |  20.00   |  $594.58 CR  |
# | 29 | 30 |   01 Jan    |                                 Account Fee                                 |   4.00   |          |  $590.58 CR  |
# | 30 | 31 |   02 Jan    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $630.58 CR  |
# | 31 | 32 |   02 Jan    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          |  $508.33 CR  |
# | 32 | 33 |   04 Jan    |                      Transfer from xx8727 CommBank app                      |          |  800.00  | $1,308.33 CR |
# | 33 | 34 |   04 Jan    |                       Transfer to xx6832 CommBank app                       |  70.00   |          | $1,238.33 CR |
# | 34 | 35 |   04 Jan    |                Direct Debit 165969 JETTS KINGSWAY2018270979                 |  27.90   |          | $1,210.43 CR |
# | 35 | 36 |   05 Jan    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $510.43 CR  |
# | 36 | 37 |   07 Jan    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $395.43 CR  |
# | 37 | 38 | 13 Jan 2018 |                               CLOSING BALANCE                               |          |          |  $395.43 CR  |
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+

# %%
import json

input = f"""Here is a transactions data in the form of a markdown table.
{markdown_table_data}

For this markdown table, give me a breakdown of the credit and debit expenses, what category they belong to, and a brief analysis of the trends you see from this transactions table. 

Return the response in JSON format with the key "result".

Example categories might include: 
- 'food and dining'
- 'lifestyle'
- 'zelle payments'
- 'monthly fee'
- 'paycheck'
- 'health and wellness'
- 'entertainment'
- 'travel and transportation'
- 'education and tuition'
- 'housing and rent'
- 'subscriptions'
- 'utilities'
- 'savings and investments'
- 'shopping'
- 'insurance'
- 'credit card payments'


### Expected JSON Output:
{{
  "result": {{
    "credits": [
      {{
        "category": "Income (Treasury Deposits)",
        "description": "Electronic Deposit From 36 TREAS 310",
        "total_amount": 29937.00,
        "transaction_count": 8,
        "notes": "Recurring deposits throughout October, peaking on Oct 4 ($11,911.98) and Oct 20 ($11,414.48)"
      }},
      {{
        "category": "Income (CGS Administrator)",
        "description": "Electronic Deposit From CGS ADMINISTATOR",
        "total_amount": 66938.03,
        "transaction_count": 9,
        "notes": "Largest deposit on Oct 4 ($11,911.98) with multiple mid-sized deposits weekly"
      }}
    ],
    "debits": [
      {{
        "category": "Food & Dining",
        "description": "VISA purchases at Panera Bread, Chick-Fil-A",
        "total_amount": 14.02,
        "transaction_count": 2
      }},
      {{
        "category": "Government Fees",
        "description": "MO SEC OF STATE payment",
        "total_amount": 51.25,
        "transaction_count": 1
      }},
      {{
        "category": "Education/Career",
        "description": "FredPryor Career Services",
        "total_amount": 149.00,
        "transaction_count": 1
      }},
      {{
        "category": "Home Maintenance",
        "description": "Plumbing services",
        "total_amount": 372.00,
        "transaction_count": 1
      }},
      {{
        "category": "Internal Transfers",
        "description": "Account transfers (145574108240/145570459670)",
        "total_amount": 45476.00,
        "transaction_count": 5,
        "notes": "Major transfers on Oct 12 ($20k total) and Oct 25 ($18,476 total)"
      }},
      {{
        "category": "Bank Fees",
        "description": "Service charges/withdrawals",
        "total_amount": 8057.45,
        "transaction_count": 6,
        "notes": "Includes $7,514.68 withdrawal from PHILA INS CO on Oct 16"
      }}
    ],
    "trends": {{
      "income_pattern": "Irregular deposit amounts with multiple sources (Treasury + CGS)",
      "spending_pattern": "Large institutional transfers dominate debits (83% of total outflows)",
      "notable_observation": "Significant mid-month activity: Oct 12-16 saw $20k in transfers + $7.5k insurance withdrawal",
      "cash_flow_alert": "High-value transfers (total $45k+) suggest active fund management between accounts",
      "recurring_expenses": "Phone bill ($308.48), insurance payments, and service charges",
      "credit_debit_ratio": {{
        "total_credits": 2018.17,
        "total_debits": 1574.19,
        "ratio": 1.28
      }}
    }}
  }}
}}
"""

print(input)
# Out:
# Here is a transactions data in the form of a markdown table.
#
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
# |    | id |    date     |                                 transaction                                 |  Debit   |  Credit  |   Balance    |
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
# | 0  | 1  | 14 Oct 2017 |                               OPENING BALANCE                               |          |          | $2,217.29 CR |
# | 1  | 2  |   15 Oct    |              Alinta Sales Pty Ltd NetBank BPAY 2733 0400032246              |  50.00   |          | $2,167.29 CR |
# | 2  | 3  |   23 Oct    |              VIRGIN MONEY NetBank BPAY 49551 4724373501635385               | 1,000.00 |          | $1,167.29 CR |
# | 3  | 4  |   23 Oct    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,097.29 CR |
# | 4  | 5  |   23 Oct    |                 Direct Debit 180247 SGIO MOT563142623171021                 |  56.42   |          | $1,040.87 CR |
# | 5  | 6  |   26 Oct    |               Direct Debit 165969 JETTS KINGSWAY 201724473788               |  27.90   |          | $1,012.97 CR |
# | 6  | 7  |   01 Nov    |                                 Account Fee                                 |   4.00   |          | $1,008.97 CR |
# | 7  | 8  |   01 Nov    |              Direct Credit 421520 JESSICA LAING JL - Internet               |          |  40.00   | $1,048.97 CR |
# | 8  | 9  |   01 Nov    |                      Transfer from xx8727 CommBank app                      |          | 1,000.00 | $2,048.97 CR |
# | 9  | 10 |   01 Nov    |                 Direct Debit 000702 HBF - HEALTH 1439123504                 |  122.25  |          | $1,926.72 CR |
# | 10 | 11 |   05 Nov    |                   Transfer to other Bank NetBank Oronsay                    |  700.00  |          | $1,226.72 CR |
# | 11 | 12 |   07 Nov    |              TELSTRA CORP LTD NetBank BPAY 23796 2000353972134              |  115.00  |          | $1,111.72 CR |
# | 12 | 13 |   09 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201725516901               |  27.90   |          | $1,083.82 CR |
# | 13 | 14 |   21 Nov    |                 Direct Debit 180247 SGIO MOT563142623171121                 |  56.42   |          | $1,027.40 CR |
# | 14 | 15 |   22 Nov    |              Direct Debit 068093 SYNERGY RETAIL B 257300733078              |  190.70  |          |  $836.70 CR  |
# | 15 | 16 |   23 Nov    |               Direct Debit 165969 JETTS KINGSWAY 201726554790               |  27.90   |          |  $808.80 CR  |
# | 16 | 17 |   01 Dec    |                                 Account Fee                                 |   4.00   |          |  $804.80 CR  |
# | 17 | 18 |   01 Dec    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $844.80 CR  |
# | 18 | 19 |   01 Dec    |                        Transfer from xx8727 NetBank                         |          | 1,000.00 | $1,844.80 CR |
# | 19 | 20 |   01 Dec    |                         Transfer to xx6832 NetBank                          |  70.00   |          | $1,774.80 CR |
# | 20 | 21 |   01 Dec    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          | $1,652.55 CR |
# | 21 | 22 |   05 Dec    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $952.55 CR  |
# | 22 | 23 |   06 Dec    | TAX OFFICE PAYMENTS NetBank BPAY 75556551004045508468221 ATO tax 2016 to 20 |  850.75  |          |  $101.80 CR  |
# | 23 | 24 |   06 Dec    |                        Transfer from xx8727 NetBank                         |          |  700.00  |  $801.80 CR  |
# | 24 | 25 |   07 Dec    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $686.80 CR  |
# | 25 | 26 |   07 Dec    |               Direct Debit 165969 JETTS KINGSWAY201727539277                |  27.90   |          |  $658.90 CR  |
# | 26 | 27 |   21 Dec    |                 Direct Debit 180247 SGIOMOT563142623171221                  |  56.42   |          |  $602.48 CR  |
# | 27 | 28 |   21 Dec    |               Direct Debit 165969 JETTS KINGSWAY201728541361                |  27.90   |          |  $574.58 CR  |
# | 28 | 29 |   27 Dec    |           Direct Credit 106600 CAMERON BROWNINGOol party thanks x           |          |  20.00   |  $594.58 CR  |
# | 29 | 30 |   01 Jan    |                                 Account Fee                                 |   4.00   |          |  $590.58 CR  |
# | 30 | 31 |   02 Jan    |               Direct Credit 421520 JESSICA LAINGJL - Internet               |          |  40.00   |  $630.58 CR  |
# | 31 | 32 |   02 Jan    |                 Direct Debit 000702 HBF - HEALTH1439123504                  |  122.25  |          |  $508.33 CR  |
# | 32 | 33 |   04 Jan    |                      Transfer from xx8727 CommBank app                      |          |  800.00  | $1,308.33 CR |
# | 33 | 34 |   04 Jan    |                       Transfer to xx6832 CommBank app                       |  70.00   |          | $1,238.33 CR |
# | 34 | 35 |   04 Jan    |                Direct Debit 165969 JETTS KINGSWAY2018270979                 |  27.90   |          | $1,210.43 CR |
# | 35 | 36 |   05 Jan    |                    Transfer to other Bank NetBankOronsay                    |  700.00  |          |  $510.43 CR  |
# | 36 | 37 |   07 Jan    |              TELSTRA CORP LTD NetBank BPAY 237962000353972134               |  115.00  |          |  $395.43 CR  |
# | 37 | 38 | 13 Jan 2018 |                               CLOSING BALANCE                               |          |          |  $395.43 CR  |
# +----+----+-------------+-----------------------------------------------------------------------------+----------+----------+--------------+
#
#
# For this markdown table, give me a breakdown of the credit and debit expenses, what category they belong to, and a brief analysis of the trends you see from this transactions table.
#
# Return the response in JSON format with the key "result".
#
# Example categories might include:
# - 'food and dining'
# - 'lifestyle'
# - 'zelle payments'
# - 'monthly fee'
# - 'paycheck'
# - 'health and wellness'
# - 'entertainment'
# - 'travel and transportation'
# - 'education and tuition'
# - 'housing and rent'
# - 'subscriptions'
# - 'utilities'
# - 'savings and investments'
# - 'shopping'
# - 'insurance'
# - 'credit card payments'
#
#
# ### Expected JSON Output:
# {
#   "result": {
#     "credits": [
#       {
#         "category": "Income (Treasury Deposits)",
#         "description": "Electronic Deposit From 36 TREAS 310",
#         "total_amount": 29937.00,
#         "transaction_count": 8,
#         "notes": "Recurring deposits throughout October, peaking on Oct 4 ($11,911.98) and Oct 20 ($11,414.48)"
#       },
#       {
#         "category": "Income (CGS Administrator)",
#         "description": "Electronic Deposit From CGS ADMINISTATOR",
#         "total_amount": 66938.03,
#         "transaction_count": 9,
#         "notes": "Largest deposit on Oct 4 ($11,911.98) with multiple mid-sized deposits weekly"
#       }
#     ],
#     "debits": [
#       {
#         "category": "Food & Dining",
#         "description": "VISA purchases at Panera Bread, Chick-Fil-A",
#         "total_amount": 14.02,
#         "transaction_count": 2
#       },
#       {
#         "category": "Government Fees",
#         "description": "MO SEC OF STATE payment",
#         "total_amount": 51.25,
#         "transaction_count": 1
#       },
#       {
#         "category": "Education/Career",
#         "description": "FredPryor Career Services",
#         "total_amount": 149.00,
#         "transaction_count": 1
#       },
#       {
#         "category": "Home Maintenance",
#         "description": "Plumbing services",
#         "total_amount": 372.00,
#         "transaction_count": 1
#       },
#       {
#         "category": "Internal Transfers",
#         "description": "Account transfers (145574108240/145570459670)",
#         "total_amount": 45476.00,
#         "transaction_count": 5,
#         "notes": "Major transfers on Oct 12 ($20k total) and Oct 25 ($18,476 total)"
#       },
#       {
#         "category": "Bank Fees",
#         "description": "Service charges/withdrawals",
#         "total_amount": 8057.45,
#         "transaction_count": 6,
#         "notes": "Includes $7,514.68 withdrawal from PHILA INS CO on Oct 16"
#       }
#     ],
#     "trends": {
#       "income_pattern": "Irregular deposit amounts with multiple sources (Treasury + CGS)",
#       "spending_pattern": "Large institutional transfers dominate debits (83% of total outflows)",
#       "notable_observation": "Significant mid-month activity: Oct 12-16 saw $20k in transfers + $7.5k insurance withdrawal",
#       "cash_flow_alert": "High-value transfers (total $45k+) suggest active fund management between accounts",
#       "recurring_expenses": "Phone bill ($308.48), insurance payments, and service charges",
#       "credit_debit_ratio": {
#         "total_credits": 2018.17,
#         "total_debits": 1574.19,
#         "ratio": 1.28
#       }
#     }
#   }
# }

# %%
from langchain_core.prompts import ChatPromptTemplate

from langchain.output_parsers import ResponseSchema, StructuredOutputParser

prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are a expert in reading markdown tables and analyzing it.",
        ),
        ("human", "{input}"),
    ]
)


chain = prompt | chat_model
message = chain.invoke(
   {
        "input": input,
    }
)

# %%
raw_response = message.content.strip()

# Remove triple backticks and the `json` label if present
if raw_response.startswith("```json"):
    raw_response = raw_response[7:]  # Remove "```json"
if raw_response.endswith("```"):
    raw_response = raw_response[:-3]  # Remove trailing "```"
try:
    response_json = json.loads(raw_response)  # Ensure it's parsed as JSON
    print(json.dumps(response_json, indent=4))
except json.JSONDecodeError:
    print("Error: Response is not valid JSON")
# Out:
# {
#     "result": {
#         "credits": [
#             {
#                 "category": "Paycheck",
#                 "description": "Direct Credit from JESSICA LAING JL - Internet",
#                 "total_amount": 120.0,
#                 "transaction_count": 3,
#                 "notes": "Recurring deposits of $40.00 on 01 Nov, 01 Dec and 02 Jan"
#             },
#             {
#                 "category": "Transfer",
#                 "description": "Transfer from xx8727 NetBank/CommBank app",
#                 "total_amount": 3500.0,
#                 "transaction_count": 4,
#                 "notes": "Recurring deposits of $1000 on 01 Nov, 01 Dec, 06 Dec and $800 on 04 Jan"
#             },
#             {
#                 "category": "Other",
#                 "description": "Direct Credit from CAMERON BROWNING Ool party thanks x",
#                 "total_amount": 20.0,
#                 "transaction_count": 1
#             }
#         ],
#         "debits": [
#             {
#                 "category": "Utilities",
#                 "description": "Alinta Sales Pty Ltd NetBank BPAY",
#                 "total_amount": 50.0,
#                 "transaction_count": 1
#             },
#             {
#                 "category": "Credit Card Payments",
#                 "description": "VIRGIN MONEY NetBank BPAY",
#                 "total_amount": 1000.0,
#                 "transaction_count": 1
#             },
#             {
#                 "category": "Internal Transfers",
#                 "description": "Transfer to xx6832 NetBank/CommBank app",
#                 "total_amount": 210.0,
#                 "transaction_count": 3,
#                 "notes": "Recurring transfers of $70.00 on 23 Oct, 01 Dec and 04 Jan"
#             },
#             {
#                 "category": "Insurance",
#                 "description": "Direct Debit SGIO MOT",
#                 "total_amount": 169.26,
#                 "transaction_count": 3,
#                 "notes": "Recurring debits of $56.42 on 23 Oct, 21 Nov and 21 Dec"
#             },
#             {
#                 "category": "Gym Membership",
#                 "description": "Direct Debit JETTS KINGSWAY",
#                 "total_amount": 111.6,
#                 "transaction_count": 4,
#                 "notes": "Recurring debits of $27.90 on 26 Oct, 09 Nov, 23 Nov and 07 Dec"
#             },
#             {
#                 "category": "Monthly Fee",
#                 "description": "Account Fee",
#                 "total_amount": 12.0,
#                 "transaction_count": 3,
#                 "notes": "Recurring debits of $4.00 on 01 Nov, 01 Dec and 01 Jan"
#             },
#             {
#                 "category": "Health and Wellness",
#                 "description": "Direct Debit HBF - HEALTH",
#                 "total_amount": 366.75,
#                 "transaction_count": 3,
#                 "notes": "Recurring debits of $122.25 on 01 Nov, 01 Dec and 02 Jan"
#             },
#             {
#                 "category": "Internal Transfers",
#                 "description": "Transfer to other Bank NetBank Oronsay",
#                 "total_amount": 1400.0,
#                 "transaction_count": 2,
#                 "notes": "Recurring transfers of $700.00 on 05 Nov and 05 Dec"
#             },
#             {
#                 "category": "Utilities",
#                 "description": "TELSTRA CORP LTD NetBank BPAY",
#                 "total_amount": 345.0,
#                 "transaction_count": 3,
#                 "notes": "Recurring debits of $115.00 on 07 Nov, 07 Dec and 07 Jan"
#             },
#             {
#                 "category": "Utilities",
#                 "description": "Direct Debit SYNERGY RETAIL B",
#                 "total_amount": 190.7,
#                 "transaction_count": 1
#             },
#             {
#                 "category": "Government Fees",
#                 "description": "TAX OFFICE PAYMENTS NetBank BPAY",
#                 "total_amount": 850.75,
#                 "transaction_count": 1
#             },
#             {
#                 "category": "Gym Membership",
#                 "description": "Direct Debit JETTS KINGSWAY",
#                 "total_amount": 55.8,
#                 "transaction_count": 2,
#                 "notes": "Recurring debits of $27.90 on 21 Dec and 04 Jan"
#             }
#         ],
#         "trends": {
#             "income_pattern": "Regular income from Jessica Laing and transfers from xx8727, with a small one-off credit from Cameron Browning.",
#             "spending_pattern": "Consistent spending on utilities (Alinta, Telstra, Synergy), insurance (SGIO), gym membership (Jetts), and health (HBF). Also includes regular internal transfers and a large credit card payment.",
#             "notable_observation": "Recurring monthly expenses for gym, health, utilities, and account fees. Large credit card payment in October and a large tax payment in December.",
#             "cash_flow_alert": "Significant outflow due to credit card payment and tax payment. Regular internal transfers suggest active fund management.",
#             "recurring_expenses": "Consistent monthly expenses for gym, health, utilities, and account fees.",
#             "credit_debit_ratio": {
#                 "total_credits": 3640.0,
#                 "total_debits": 3772.76,
#                 "ratio": 0.96
#             }
#         }
#     }
# }
